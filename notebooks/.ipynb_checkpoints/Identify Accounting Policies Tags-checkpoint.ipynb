# %% [markdown]
# In this notebook, I examine the XBRL tags firms use to identify their "Significant Accounting Policies" in their 10-K. Most firms use simply the "SignificantAccountingPoliciesTextBlock" tag, but there are lots that do not. I will use the "Financial Statements and Notes Datasets" from EDGAR and some heuristic searches to identify the relevant tags.

# %%
import pandas as pd
import os
import urllib
import zipfile

# %%
EXT_DIR = "/media/reggie/reg_ext/EDGAR/FSANDS/"

# %%
def unzip_fsands(year, quarter):
    target_filename = os.path.join(EXT_DIR, 'zips',str(year)+'q'+str(quarter)+'.zip')
    target_dir = os.path.join(EXT_DIR, 'unzipped',str(year)+'q'+str(quarter))
    print(target_dir)
    if not os.path.isdir(target_dir):
        os.makedirs(target_dir)
    with zipfile.ZipFile(target_filename, 'r') as zip_ref:
        zip_ref.extractall(target_dir)
def extract_fsands(filepath):
    print(filepath)

    with open(filepath, "r", encoding='latin1') as infile:
        contents = infile.readlines()

    data = [line.strip().split("\t") for line in contents]
    bads = []
    goods = []
    for line in data:
        if len(line) == 20:
            goods.append(line)
        else:
            bads.append(line)

    with open(filepath.replace(".tsv","") + "-clean.tsv", "w") as outfile:
        outfile.writelines(["\t".join(line)+"\n" for line in goods])
    with open(filepath.replace(".tsv","") + "-bad.tsv", "w") as outfile:
        outfile.writelines(["\t".join(line)+"\n" for line in bads])
        
    print(len(goods), " goods and ",len(bads),"bads in ",filepath)
    
def get_sap(txt_submissions, form_type, year, quarter):
    x = pd.read_csv(txt_submissions, sep="\t", low_memory=False)
    ## Merge CIK numbers
    subs = pd.read_csv(EXT_DIR+"/unzipped/{}q{}/sub.tsv".format(year, quarter), sep="\t")
    subs_10k = subs[subs["form"].apply(lambda x: str(x).find(form_type) > -1)]
    ciks = subs_10k[["adsh","cik","sic","form","period","fye","fp","filed"]]
    sap = x[x["tag"] == "SignificantAccountingPoliciesTextBlock"]
    sap = sap.merge(ciks)
    sap.to_csv(EXT_DIR + "/SAP/{}q{}.tsv".format(year, quarter), sep="\t", index=False)

# %%
year=2017
quarter = 2
unzip_fsands(year, quarter)
txt_submissions = os.path.join(EXT_DIR, "unzipped/{}q{}/txt.tsv".format(year,quarter))
extract_fsands(txt_submissions)
get_sap(txt_submissions.replace(".tsv","-clean.tsv"), "10-K",year, quarter)
# Out:
# /media/reggie/reg_ext/EDGAR/FSANDS/unzipped/2017q2
# /media/reggie/reg_ext/EDGAR/FSANDS/unzipped/2017q2/txt.tsv
# 483814  goods and  272 bads in  /media/reggie/reg_ext/EDGAR/FSANDS/unzipped/2017q2/txt.tsv

# %%
sap = pd.read_csv(EXT_DIR+"/SAP/2017q2.tsv", sep="\t", low_memory=False)
print(sap.shape)
sap.head()
# Out:
# (629, 27)
#                    adsh                                     tag       version  \
# 0  0001437749-17-005927  SignificantAccountingPoliciesTextBlock  us-gaap/2016
# 1  0001493152-17-003990  SignificantAccountingPoliciesTextBlock  us-gaap/2017
# 2  0001213900-17-006991  SignificantAccountingPoliciesTextBlock  us-gaap/2016
# 3  0001615774-17-001500  SignificantAccountingPoliciesTextBlock  us-gaap/2016
# 4  0001096906-17-000396  SignificantAccountingPoliciesTextBlock  us-gaap/2017
#
#       ddate  qtrs  iprx   lang   dcml      durp  datp  ... footlen  \
# 0  20161231     4     0  en-US  32767 -0.054794  -2.0  ...       0
# 1  20161231     4     0  en-US  32767  0.000000   0.0  ...       0
# 2  20170331     4     0  en-US  32767  0.010959   0.0  ...       0
# 3  20161231     4     0  en-US  32767  0.000000   0.0  ...       0
# 4  20161231     4     0  en-US  32767  0.000000   0.0  ...       0
#
#                                              context  \
# 0                            d_2015-12-29_2017-01-02
# 1                         From2016-01-01to2016-12-31
# 2  Context_FYE_01_Apr_2016T00_00_00_TO_31_Mar_201...
# 3                         From2016-01-01to2016-12-31
# 4                                                Y16
#
#                                                value      cik     sic    form  \
# 0  Note 2Significant Accounting Policies Principl...  1526796  5812.0    10-K
# 1  NOTE 2  SUMMARY OF SIGNIFICANT ACCOUNTING POLI...  1444144  8000.0    10-K
# 2  3. Summary of Significant Accounting Policies ...  1681941  5411.0    10-K
# 3  NOTE 2 - Summary of Significant Accounting Pol...  1537663  2834.0    10-K
# 4  1. SUMMARY OF SIGNIFICANT ACCOUNTING POLICIES ...  1131089  3949.0  10-K/A
#
#      period     fye  fp     filed
# 0  20161231  1231.0  FY  20170403
# 1  20161231  1231.0  FY  20170417
# 2  20170331   331.0  FY  20170629
# 3  20161231  1231.0  FY  20170405
# 4  20161231  1231.0  FY  20170526
#
# [5 rows x 27 columns]

# %%
#subs = pd.read_csv(EXT_DIR+"/unzipped/2017q2/sub.tsv", sep="\t", low_memory=False)
subs = pd.read_csv(EXT_DIR+"/all-sub.tsv", sep="\t", low_memory=False)
subs.head()
# Out:
#                    adsh    cik                           name     sic  \
# 0  0000006207-13-000031   6207                    AMREP CORP.  6500.0
# 1  0000008670-13-000015   8670  AUTOMATIC DATA PROCESSING INC  7374.0
# 2  0000008858-13-000011   8858                      AVNET INC  5065.0
# 3  0000014195-13-000016  14195         BRIGGS & STRATTON CORP  3510.0
# 4  0000016732-13-000023  16732               CAMPBELL SOUP CO  2000.0
#
#   countryba stprba     cityba  zipba                    bas1       bas2  ...  \
# 0        US     NJ  PRINCETON  08540      300 ALEXANDER PARK  SUITE 204  ...
# 1        US     NJ   ROSELAND  07068        ONE ADP BOULVARD        NaN  ...
# 2        US     AZ    PHOENIX  85034  2211 SOUTH 47TH STREET        NaN  ...
# 3        US     WI  WAUWATOSA  53222        12301 W WIRTH ST        NaN  ...
# 4        US     NJ     CAMDEN  08103             CAMPBELL PL        NaN  ...
#
#                 accepted prevrpt detail          instance nciks aciks  \
# 0  2013-07-16 08:16:00.0       0      1  axr-20130430.xml     1   NaN
# 1  2013-08-19 12:00:00.0       0      1  adp-20130630.xml     1   NaN
# 2  2013-08-09 07:00:00.0       0      1  avt-20130629.xml     1   NaN
# 3  2013-08-27 14:59:00.0       0      1  bgg-20130630.xml     1   NaN
# 4  2013-09-26 07:43:00.0       0      1  cpb-20130728.xml     1   NaN
#
#     pubfloatusd   floatdate floataxis  floatmems
# 0  1.848270e+07  20121031.0       NaN        NaN
# 1  2.756094e+10  20130630.0       NaN        NaN
# 2  4.058518e+09  20121228.0       NaN        NaN
# 3  7.701000e+08  20121228.0       NaN        NaN
# 4  6.774117e+09  20130127.0       NaN        NaN
#
# [5 rows x 40 columns]

# %%
linkbase = "https://www.sec.gov/Archives/edgar/data/"
urls = []
for i, row in subs.iterrows():
    instance = row["instance"]
    adsh = row["adsh"]
    url = linkbase + str(int(adsh.split("-")[0])) + "/"+adsh.replace("-","") + "/" + instance
    urls.append(url)

# %%
q = {1:1,2:1,3:1,4:2,5:2,6:2,7:3,8:3,9:3,10:4,11:4,12:4}
for i, row in subs.iterrows():
    file_date = str(row['filed'])
    year = int(file_date[:4])
    month = int(file_date[4:6])
    quarter = q[month]
    adsh = row["adsh"]
    url = row["url"]
    
    DOWNLOAD_DIR = "/home/reggie/EDGAR/xbrl-2/{}/{}".format(year, quarter)
    if not os.path.isdir(DOWNLOAD_DIR):
        os.makedirs(DOWNLOAD_DIR)
    
    target_filepath = os.path.join(DOWNLOAD_DIR,adsh+".xml")
    
    if not os.path.isfile(target_filepath):
        print("Downloading {} of {}, file: {} ...".format(i, subs.shape[0], target_filepath))
        urllib.request.urlretrieve(url, target_filepath)
    else:
        print("File {} already exists...".format(target_filepath))
# Out:
# File /home/reggie/EDGAR/xbrl-2/2013/3/0000006207-13-000031.xml already exists...
# File /home/reggie/EDGAR/xbrl-2/2013/3/0000008670-13-000015.xml already exists...
# File /home/reggie/EDGAR/xbrl-2/2013/3/0000008858-13-000011.xml already exists...
# File /home/reggie/EDGAR/xbrl-2/2013/3/0000014195-13-000016.xml already exists...
# File /home/reggie/EDGAR/xbrl-2/2013/3/0000016732-13-000023.xml already exists...
# File /home/reggie/EDGAR/xbrl-2/2013/3/0000018498-13-000039.xml already exists...
# File /home/reggie/EDGAR/xbrl-2/2013/3/0000023666-13-000014.xml already exists...
# File /home/reggie/EDGAR/xbrl-2/2013/3/0000039047-13-000065.xml already exists...
# File /home/reggie/EDGAR/xbrl-2/2013/3/0000039648-13-000016.xml already exists...
# File /home/reggie/EDGAR/xbrl-2/2013/3/0000046640-13-000018.xml already exists...
# File /home/reggie/EDGAR/xbrl-2/2013/3/0000055242-13-000017.xml already exists...
# File /home/reggie/EDGAR/xbrl-2/2013/3/0000055772-13-000016.xml already exists...
# File /home/reggie/EDGAR/xbrl-2/2013/3/0000056701-13-000033.xml already exists...
# File /home/reggie/EDGAR/xbrl-2/2013/3/0000061398-13-000062.xml already exists...
# File /home/reggie/EDGAR/xbrl-2/2013/3/0000065011-13-000104.xml already exists...
# File /home/reggie/EDGAR/xbrl-2/2013/3/0000066382-13-000032.xml already exists...
# File /home/reggie/EDGAR/xbrl-2/2013/3/0000067215-13-000046.xml already exists...
# File /home/reggie/EDGAR/xbrl-2/2013/3/0000067472-13-000007.xml already exists...
# File /home/reggie/EDGAR/xbrl-2/2013/3/0000068270-13-000036.xml already exists...
# File /home/reggie/EDGAR/xbrl-2/2013/3/0000070502-13-000299.xml already exists...
# File /home/reggie/EDGAR/xbrl-2/2013/3/0000075829-13-000007.xml already exists...
# File /home/reggie/EDGAR/xbrl-2/2013/3/0000076334-13-000157.xml already exists...
# File /home/reggie/EDGAR/xbrl-2/2013/3/0000080424-13-000063.xml already exists...
# File /home/reggie/EDGAR/xbrl-2/2013/3/0000087802-13-000010.xml already exists...
# File /home/reggie/EDGAR/xbrl-2/2013/3/0000096021-13-000073.xml already exists...
# Downloading 25 of 51810, file: /home/reggie/EDGAR/xbrl-2/2013/3/0000096536-13-000018.xml ...
# Downloading 26 of 51810, file: /home/reggie/EDGAR/xbrl-2/2013/3/0000097472-13-000023.xml ...
# Downloading 27 of 51810, file: /home/reggie/EDGAR/xbrl-2/2013/3/0000098618-13-000011.xml ...
# Downloading 28 of 51810, file: /home/reggie/EDGAR/xbrl-2/2013/3/0000098752-13-000006.xml ...
# Downloading 29 of 51810, file: /home/reggie/EDGAR/xbrl-2/2013/3/0000100378-13-000044.xml ...
# Downloading 30 of 51810, file: /home/reggie/EDGAR/xbrl-2/2013/3/0000108385-13-000032.xml ...
# Downloading 31 of 51810, file: /home/reggie/EDGAR/xbrl-2/2013/3/0000109563-13-000029.xml ...
# Downloading 32 of 51810, file: /home/reggie/EDGAR/xbrl-2/2013/3/0000277375-13-000045.xml ...
# Downloading 33 of 51810, file: /home/reggie/EDGAR/xbrl-2/2013/3/0000310354-13-000023.xml ...
# Downloading 34 of 51810, file: /home/reggie/EDGAR/xbrl-2/2013/3/0000316793-13-000024.xml ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-80-6b4e83b07fb2> in <module>
#      16     if not os.path.isfile(target_filepath):
#      17         print("Downloading {} of {}, file: {} ...".format(i, subs.shape[0], target_filepath))
# ---> 18         urllib.request.urlretrieve(url, target_filepath)
#      19     else:
#      20         print("File {} already exists...".format(target_filepath))
#
# ~/anaconda3/lib/python3.7/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     274
#     275             while True:
# --> 276                 block = fp.read(bs)
#     277                 if not block:
#     278                     break
#
# ~/anaconda3/lib/python3.7/http/client.py in read(self, amt)
#     455             # Amount is given, implement using readinto
#     456             b = bytearray(amt)
# --> 457             n = self.readinto(b)
#     458             return memoryview(b)[:n].tobytes()
#     459         else:
#
# ~/anaconda3/lib/python3.7/http/client.py in readinto(self, b)
#     489
#     490         if self.chunked:
# --> 491             return self._readinto_chunked(b)
#     492
#     493         if self.length is not None:
#
# ~/anaconda3/lib/python3.7/http/client.py in _readinto_chunked(self, b)
#     589
#     590                 if len(mvb) <= chunk_left:
# --> 591                     n = self._safe_readinto(mvb)
#     592                     self.chunk_left = chunk_left - n
#     593                     return total_bytes + n
#
# ~/anaconda3/lib/python3.7/http/client.py in _safe_readinto(self, b)
#     634                 n = self.fp.readinto(temp_mvb)
#     635             else:
# --> 636                 n = self.fp.readinto(mvb)
#     637             if not n:
#     638                 raise IncompleteRead(bytes(mvb[0:total_bytes]), len(b))
#
# ~/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~/anaconda3/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# ~/anaconda3/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
